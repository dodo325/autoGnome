# %%
import bash_builder as bb
from bash_builder import get_subdirs_list, get_script_dependences_order, collect_scripts, get_scripts_list

# %%
scripts = get_scripts_list()
scripts
# Out:
# {'GIT': {'name': 'GIT',
#   'tags': ['VCS', 'Programm', 'CLI'],
#   'dependence': [],
#   'installers': {'default': 'install.sh'}},
#  'Telegram': {'name': 'Telegram',
#   'tags': ['Messager'],
#   'dependence': [],
#   'installers': {'default': 'install.sh'}},
#  'Audacity': {'name': 'Audacity',
#   'tags': ['Audio editor', 'Programm', 'GUI'],
#   'dependence': [],
#   'installers': {'default': 'install.sh'}},
#  'Nautilus Terminal 3': {'name': 'Nautilus Terminal 3',
#   'tags': ['GUI', 'Programm', 'CLI'],
#   'dependence': [],
#   'installers': {'default': 'install.sh'}},
#  'Docker': {'name': 'Docker',
#   'tags': ['Containers', 'Programm', 'CLI'],
#   'dependence': [],
#   'installers': {'default': 'install.sh'}},
#  'Kite': {'name': 'Nautilus',
#   'tags': ['GUI', 'Programm', 'CLI', 'AI', 'Tool'],
#   'dependence': ['VSCode'],
#   'installers': {'default': 'install.sh'}},
#  'VSCode': {'name': 'VSCode',
#   'tags': ['IDE', 'Programm', 'GUI', 'IDE'],
#   'dependence': [],
# ...

# %%
names = get_script_dependences_order(scripts, 'Django')
names
# Out:
# ['Anaconda', 'Django']

# %%
collect_scripts(names, scripts)

# %%
tags = set()
for name, data in scripts.items():
        tags.update(data['tags'])
tags
# Out:
# {'AI',
#  'Audio editor',
#  'BitTorrent',
#  'Browser',
#  'CLI',
#  'Client',
#  'Containers',
#  'Framework',
#  'GUI',
#  'Graphics editor',
#  'IDE',
#  'Media player',
#  'Messager',
#  'P2P',
#  'Platform',
#  'Platform ',
#  'Programm',
#  'Programm language',
#  'Python',
#  'SSH',
#  'Screen',
#  'Tool',
#  'VCS',
#  'VM',
#  'Voice & text chat app',
#  'Web',
#  'Windows',
#  'framework',
#  'terminal'}

# %%
graph = {
    'a': ['b', 'c'],
    'b': ['d'],
    'c': ['d'],
    'd': ['e'],
    'e': []
}
print(recursive_topological_sort(graph, 'b'))
# Out:
# ['b', 'd', 'e']

# %%
print(recursive_topological_sort(graph, 'Django'))
# Out:
# ['Django', 'Anaconda']

# %%
s

# %%
# test

# %%
ffs = ['bigascii12.tlf', 'double', 'smtengwar', 'rally_s2', 'alphabet', 'small', 'kik_star', 'gothic__', 'chunky', 'ticksslant', 'triad_st', 'home_pak', 'mshebrew210', 'charact1', 'bell', 'sbookb', 'ti_pan__', 'calgphy2', 'charact6', 'upper.flc', 'xcour', 'xbriteb', 'ntgreek', 'utopia', 'bulbhead', 'banner', 'clr7x10', 'mini', 'stampatello', 'letter.tlf', 'xsbookbi', 'charact5', 'chartri', 'thin', 'roman___', 'clr8x10', 'helvi', 'funky_dr', 'stencil1', 't__of_ap', 'top_duck', 'linux', 'thick', 'chartr', 'peaks', 'zig_zag_', 'battle_s', 'lazy_jon', 'script', 'moscow', 'hyper___', 'ttyb', 'pepper', 'xbritebi', 'poison', 'smslant', 'fender', 'clr5x6', 'caligraphy', 'greek', 'wavy', 'char2___', 'ebbs_2__', 'charact3', 'hypa_bal', 'nancyj-underlined', 'speed', 'e__fist_', 'smshadow', 'digital', 'dotmatrix', 'cricket', 'grand_pr', 'xcourbi', 'phonix__', 'tsm_____', 'slant', 'sbooki', 'sansbi', 'rok_____', 'sansi', 'fbr_stri', 'goofy', 'mig_ally', 'xbrite', 'rainbow_', 'tubular', 'bigmono9.tlf', 'short', 'eftifont', 'xsbook', 'smisome1', 'charset_', 'lower.flc', 'britebi', 'fraktur', '__init__.py', 'drpepper', 'nfi1____', 'rot13', 'tombstone', 'future_5', 'basic', 'unarmed_', 'c1______', 'dwhistled', 'rad_phan', 'letterw3', 'smkeyboard', 'clr6x8', 'rectangles', 'atc_gran', 'twopoint', '64f1____', 'whimsy', 'pawp', 'future_2', 'ascii9.tlf', 'zone7___', 'alligator2', 'type_set', 'avatar', 'demo_1__', '5x7', 'couri', 'smmono12.tlf', 'isometric1', 'bubble_b', 'mono9.tlf', 'nvscript', 'smascii9.tlf', 'ok_beer_', 'maxfour', 'hollywood', 'lean', 'serifcap', 'advenger', 'notie_ca', 'future_8', 'banner4', 'platoon2', 'contrast', 'trek', 'raw_recu', 'rockbox_', 'devilish', '5x8', 'charact2', 'faces_of', 'sans', 'street_s', 'binary', 'demo_m__', 'smbraille.tlf', 'xsansi', 'ogre', 'rozzo', 'usa_pq__', 'graffiti', 'odel_lak', 'jazmine', 'skate_ro', 'joust___', 'diamond', 'xsbookb', 'straight', 'tanja', 'xcouri', 'ivrit', 'fireing_', 'nancyj-fancy', 'cosmic', 'term', 'xttyb', 'cour', 'tec_7000', 'clr4x6', 'eftirobot', 'pod_____', 'lcd', 'usa_____', 'pagga.tlf', 'fantasy_', 'circle.tlf', 'clb6x10', 'fbr12___', 'italic', 'spc_demo', 'standard', 'a_zooloo', 'katakana', 'flyn_sh', 'clr6x10', 'sm______', 'timesofl', 'mad_nurs', 'xbritei', 'master_o', 'sansb', 'emboss.tlf', 'xsans', 'sbookbi', 'tav1____', 'marquee', 'colossal', 'broadway', 'characte', 'ugalympi', 'rot13.flc', 'ebbs_1__', 'block', 'doom', 'tengwar', 'tomahawk', 'brite', 'arrows', 'xtimes', 'nancyj', '6x9', 'helvb', 'future_4', 'tty', 'mnemonic', 'trashman', 'deep_str', 'italics_', 'eftitalic', 'rowancap', 'ucf_fan_', 'null.flc', 'fbr_tilt', 'battlesh', 'doh', 'contessa', 'letter_w', 'beer_pub', 'cybersmall', 'demo_2__', 'char4___', 'xhelv', 'invita', 'stacey', 'house_of', 'taxi____', 'ticks', 'octal', 'charact4', 'z-pilot_', 'panther_', 'times', 'krak_out', 'helvbi', 'future_1', 'barbwire', 'clr6x6', 'pawn_ins', 'epic', 'weird', 'ascii12.tlf', 'coil_cop', 'tiles', 'crawford', 'eca_____', 'xchartr', 'larry3d', 'skateroc', 'relief2', 'roman', 'xsansb', 'outrun__', '6x10', 'nipples', 'pyramid', 'asslt__m', 'briteb', 'bubble', 'high_noo', 'aquaplan', 'fuzzy', 'os2', 'mono12.tlf', 'gauntlet', 'courb', 'space_op', 'stellar', 'xsansbi', 'utopiai', 'hex', 'c_consen', 'druid___', 'fp1_____', 'threepoint', '3-d', 'char3___', 'fbr1____', 'isometric3', 'gothic', 'script__', 'tinker-toy', 'lockergnome', 'stencil2', 'xhelvb', 'emboss2.tlf', 'yie_ar_k', 'c2______', 'bigmono12.tlf', 'mcg_____', 'slide', 'tsn_base', 'rev', 'letters', 'rounded', 'computer', 'defleppard', 'r2-d2___', 'bubble__', 'starwars', 'c_ascii_', 'helv', 'o8', 'future_3', 'sbook', 'rastan__', 'npn_____', 'subteran', 'alligator', 'tecrvs__', 'bigchief', 'runyc', 'sketch_s', 'rci_____', 'fbr2____', 'future_7', 'ghost_bo', 'cyberlarge', 'road_rai', 'cosmike', 'hills___', 'tec1____', 'xhelvi', 'jerusalem', 'new_asci', 'kban', 'sblood', 'baz__bil', 'mayhem_d', 'smascii12.tlf', 'p_s_h_m_', 'bigascii9.tlf', 'b_m__200', 'xcourb', 'assalt_m', 'mike', 'atc_____', 'platoon_', 'banner3-D', 'future_6', 'banner3', 'fourtops', 'vortron_', 'eftiwater', 'magic_ma', 'etcrvs__', 'hades___', 'd_dragon', 'kgames_i', 'clr5x10', 'cybermedium', 'com_sen_', 'ascii___', 'p_skateb', 'yie-ar__', 'xtty', 'shadow', 'ripper!_', 'ts1_____', 'inc_raw_', 'rally_sp', 'relief', 'clr8x8', 'eftipiti', 'fp2_____', 'cursive', 'catwalk', 'utopiabi', 'big', '4x4_offr', 'coinstak', 'puffy', 'morse', 'skateord', 'runic', 'acrobatic', 'finalass', 'smblock.tlf', 'britei', 'gradient', 'cli8x8', 'rampage_', 'xchartri', 'caus_in_', 'heavy_me', 'twin_cob', 'clb8x10', 'future.tlf', 'wideterm.tlf', 'f15_____', 'utopiab', 'slscript', 'eftichess', 'univers', 'war_of_w', 'pacos_pe', 'stop', 'modern__', 'super_te', 'eftiwall', 'smmono9.tlf', 'dcs_bfmo', 'tsalagi', 'shimrod', 'isometric2', '3x5', 'mirror', 'fairligh', 'courbi', '1943____', 'usaflag', 'green_be', 'convoy__', '5lineoblique', 'xsbooki', 'clr7x8', 'pebbles', 'radical_', 'star_war', 'fair_mea', 'char1___', 'asc_____', 'xhelvbi', 'madrid', 'lexible_', 'graceful', 'smscript', 'decimal', 'clr5x8', 'stealth_', 'heroboti', 'clb8x8', 'rad_____', 'isometric4']

# %%
from pyfiglet import figlet_format
from termcolor import cprint
import sys

# %%
cprint(figlet_format("Auto Gnome", font='epic'), "red")
# Out:
#  _______          _________ _______
# (  ___  )|\     /|\__   __/(  ___  )
# | (   ) || )   ( |   ) (   | (   ) |
# | (___) || |   | |   | |   | |   | |
# |  ___  || |   | |   | |   | |   | |
# | (   ) || |   | |   | |   | |   | |
# | )   ( || (___) |   | |   | (___) |
# |/     \|(_______)   )_(   (_______)
#
#  _______  _        _______  _______  _______
# (  ____ \( (    /|(  ___  )(       )(  ____ \
# | (    \/|  \  ( || (   ) || () () || (    \/
# | |      |   \ | || |   | || || || || (__
# | | ____ | (\ \) || |   | || |(_)| ||  __)
# | | \_  )| | \   || |   | || |   | || (
# | (___) || )  \  || (___) || )   ( || (____/\
# (_______)|/    )_)(_______)|/     \|(_______/

# %%
for f in ffs:
    try:
        print(f"\n****** font = {f}:")
        
        
    except Exception as e:
        pass
# Out:
# ****** font = bigascii12.tlf:
#
# ****** font = double:
#  ___ __ ________ ___       ___ __  __  ___  ___  ___ ____
# // \\|| ||| || |// \\     // \\||\ || // \\ ||\\//||||
# ||=|||| ||  || ((   ))   (( ___||\\||((   ))|| \/ ||||==
# || ||\\_//  ||  \\_//     \\_|||| \|| \\_// ||    ||||___
#
#
#
# ****** font = smtengwar:
# .', ?     c  _____  _ _  c  _ _  ,'
#  |  | |~) |  (_(_| | ) ) | |_)_)  |
#       |          |
#
#
# ****** font = rally_s2:
#   ###     #         #  # ###
#  ####  #####  # # #      ###
#   ###  # #  # #   ###### ###
#   ###   ##      # ##   # ###
# #######   ##     ##   #  #######
# ####### ## #  # #  #   # #######
# ####### #        ##
#        #    # # #   #   ##    ##
# ####### ######    ###     ###### #######
#     ### ##  ##    ###     ##  ##  ######
#    ####    ####   ###        ##    #####
#   ####    ##  ##  ###       ###    #####
#  #####       ##   #######    ##   ######
# #####       ##    #######    ##  #######
# ...
